# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import time
print('Ready!')
# Out:
# Ready!

# %%
# load data
def load_fit_data():
    dataset = read_csv('fit_test.csv')
    dataset = dataset[['loss','val_loss','acc','val_acc']]
    return dataset

def update_plots(ax, df):
    ax[0].clear()
    ax[0].plot(df.index, df.loss, color='b')
    ax[0].plot(df.index, df.val_loss, color='g')
    ax[0].legend(['loss','val_loss'], loc='upper right')
    #ax[0].title('Loss', loc='right')
    ax[1].clear()
    ax[1].plot(df.index, df.acc, color='b')
    ax[1].plot(df.index, df.val_acc, color='g')
    ax[1].legend(['acc','val_ac'], loc='lower right')
    #ax[1].title('Accuracy', loc='right')
    fig.canvas.draw()
    


#------------------------------------------------------
fig,ax = plt.subplots(2,1)
while True:
  try:
    df = load_fit_data()          
  except:
    df = pd.DataFrame(data=[[0],[0],[0],[0]], columns=['loss','val_loss','acc','val_acc'])
  update_plots(ax, df)
  time.sleep(10)
# Out:
# <img src="data:image/png;base64,..." width="640">
