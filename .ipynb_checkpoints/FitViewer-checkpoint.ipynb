# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import time
print('Ready!')
# Out:
# Ready!

# %%
# load data
def load_fit_data():
    dataset = read_csv('fit.csv')
    dataset = dataset[['loss','val_loss','acc','val_acc']]
    return dataset

def update_plots(ax, df):
    ax[0].clear()
    ax[0].plot(df.index, df.loss, color='b')
    ax[0].plot(df.index, df.val_loss, color='g')
    ax[0].legend(['loss','val_loss'], loc='upper right')
    #ax[0].title('Loss', loc='right')
    ax[1].clear()
    ax[1].plot(df.index, df.acc, color='b')
    ax[1].plot(df.index, df.val_acc, color='g')
    ax[1].legend(['acc','val_ac'], loc='lower right')
    #ax[1].title('Accuracy', loc='right')
    fig.canvas.draw()
    


#------------------------------------------------------
fig,ax = plt.subplots(2,1)
while True:
  try:
    df = load_fit_data()          
  except:
    df = pd.DataFrame(data=[[0],[0],[0],[0]], columns=['loss','val_loss','acc','val_acc'])
  update_plots(ax, df)
  time.sleep(10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\site-packages\IPython\core\interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-0b36845fb1d8>", line 30, in <module>
#     time.sleep(10)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\site-packages\IPython\core\interactiveshell.py", line 2016, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\site-packages\IPython\core\ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\site-packages\IPython\core\ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\raulm\Programas\anaconda3\envs\keras\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
