# %% [markdown]
# # Introduction
#
# En este punto, tengo unificados los dataframes de las tres temporalidades. Partiendo que la temporalidad más baja es en la que se realizará la operativa, hay que seleccionar aquellos estados en los que se cumpla que la columna FLIP esté activa (True), que son los momentos en los que se detecta un nuevo flip de estado.
#
# Los pasos a realizar son éstos:
#
# * Cargar los archivos 'merged' de cada instrumento
# * Seleccionar las entradas con FLIP==True en la temporalidad más baja
# * Selecciono las variables útiles entre las diversas FUZ_...
# * Guardar dataframes en ./filtered
# * Formar el vector de entrada-salida con el loopback y la predicción
# * Dividir en grupos de entrenamiento y validación
# * Guardar los diferentes grupos en dataframes para una posterior recarga.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import required packages
# Append relative path to FuzzyMarketState.py
import os
import sys
sys.path.append('../../common/')

from FuzzyMarketState import FuzzyMarketState
from FuzzyLib import Fuzzifier, FuzzyVar
import MyUtils

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.tools import FigureFactory as FF
import plotly.tools as tls
plotly.offline.init_notebook_mode(connected=True)

import logging
logging.basicConfig(level=logging.DEBUG, stream=sys.stdout)

import pandas as pd
import random
import datetime

print('Packages loaded!!')
# Out:
# Using TensorFlow backend.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Packages loaded!!
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %% [markdown]
# #### Cargo archivos 'merged'

# %%
# for each forex-pair load each timeframe
path = '../csv_data/indicators/fuzzified/merged'
items = dict()
fms = 'fms'

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
  for file in f: 
    # file has format: SYMBOL_h1h4d1.csv
    tokens = file.split('_')
    print('tokens={}'.format(tokens))
    if len(tokens) == 2:
      symbol = tokens[0]
      if symbol not in items.keys():
        print('New item: {}', symbol)
        item_file = '{}/{}'.format(path, file)
        print('loading csv file: {}'.format(item_file))
        items[symbol] = {'file' : item_file, 'df' : pd.read_csv(item_file, sep=';')}
        print('loaded {} rows'.format(items[symbol]['df'].shape[0]))
        print('+++++++++++++++++++++++++++++++++++++')
# Out:
# tokens=['AUDUSD', 'h1h4d1.csv']
# New item: {} AUDUSD
# loading csv file: ../csv_data/indicators/fuzzified/merged/AUDUSD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURAUD', 'h1h4d1.csv']
# New item: {} EURAUD
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURAUD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURCAD', 'h1h4d1.csv']
# New item: {} EURCAD
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURCAD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURCHF', 'h1h4d1.csv']
# New item: {} EURCHF
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURCHF_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURGBP', 'h1h4d1.csv']
# New item: {} EURGBP
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURGBP_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURJPY', 'h1h4d1.csv']
# New item: {} EURJPY
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURJPY_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURNZD', 'h1h4d1.csv']
# New item: {} EURNZD
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURNZD_h1h4d1.csv
# loaded 2452 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['EURUSD', 'h1h4d1.csv']
# New item: {} EURUSD
# loading csv file: ../csv_data/indicators/fuzzified/merged/EURUSD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['GBPCAD', 'h1h4d1.csv']
# New item: {} GBPCAD
# loading csv file: ../csv_data/indicators/fuzzified/merged/GBPCAD_h1h4d1.csv
# loaded 2459 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['GBPJPY', 'h1h4d1.csv']
# New item: {} GBPJPY
# loading csv file: ../csv_data/indicators/fuzzified/merged/GBPJPY_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['GBPUSD', 'h1h4d1.csv']
# New item: {} GBPUSD
# loading csv file: ../csv_data/indicators/fuzzified/merged/GBPUSD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['NZDUSD', 'h1h4d1.csv']
# New item: {} NZDUSD
# loading csv file: ../csv_data/indicators/fuzzified/merged/NZDUSD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['USDCAD', 'h1h4d1.csv']
# New item: {} USDCAD
# loading csv file: ../csv_data/indicators/fuzzified/merged/USDCAD_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['USDCHF', 'h1h4d1.csv']
# New item: {} USDCHF
# loading csv file: ../csv_data/indicators/fuzzified/merged/USDCHF_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++
# tokens=['USDJPY', 'h1h4d1.csv']
# New item: {} USDJPY
# loading csv file: ../csv_data/indicators/fuzzified/merged/USDJPY_h1h4d1.csv
# loaded 2453 rows
# +++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Selección de eventos FLIP == True en temporalidad más baja

# %%
# check columns with FLIP text
for symbol in items.keys():
  df = items[symbol]['df']
  log_columns = ''
  for c in df.columns:
    if 'FLIP' in c:
      log_columns += ' {}'.format(c)
  print('FLIP columns in {} = {}'.format(symbol, log_columns))
  print('+++++++++++++++++++++++++++++++++++++')
# Out:
# FLIP columns in AUDUSD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURAUD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURCAD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURCHF =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURGBP =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURJPY =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURNZD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in EURUSD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in GBPCAD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in GBPJPY =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in GBPUSD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in NZDUSD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in USDCAD =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in USDCHF =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++
# FLIP columns in USDJPY =  h1_FLIP h4_FLIP d1_FLIP
# +++++++++++++++++++++++++++++++++++++

# %%
# filter rows where h1_FLIP == True
for symbol in items.keys():
  df = items[symbol]['df']
  items[symbol]['df_filtered'] = df[(df.h1_FLIP == True)].copy()
  print('Selected {} rows in {}'.format(items[symbol]['df_filtered'].shape[0], symbol))
  print('+++++++++++++++++++++++++++++++++++++')
# Out:
# Selected 423 rows in AUDUSD
# +++++++++++++++++++++++++++++++++++++
# Selected 398 rows in EURAUD
# +++++++++++++++++++++++++++++++++++++
# Selected 367 rows in EURCAD
# +++++++++++++++++++++++++++++++++++++
# Selected 369 rows in EURCHF
# +++++++++++++++++++++++++++++++++++++
# Selected 382 rows in EURGBP
# +++++++++++++++++++++++++++++++++++++
# Selected 402 rows in EURJPY
# +++++++++++++++++++++++++++++++++++++
# Selected 330 rows in EURNZD
# +++++++++++++++++++++++++++++++++++++
# Selected 359 rows in EURUSD
# +++++++++++++++++++++++++++++++++++++
# Selected 307 rows in GBPCAD
# +++++++++++++++++++++++++++++++++++++
# Selected 421 rows in GBPJPY
# +++++++++++++++++++++++++++++++++++++
# Selected 380 rows in GBPUSD
# +++++++++++++++++++++++++++++++++++++
# Selected 417 rows in NZDUSD
# +++++++++++++++++++++++++++++++++++++
# Selected 350 rows in USDCAD
# +++++++++++++++++++++++++++++++++++++
# Selected 379 rows in USDCHF
# +++++++++++++++++++++++++++++++++++++
# Selected 410 rows in USDJPY
# +++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Selección de variables FUZ_...
#
# Hay que seleccionar las variables que den información sobre el estado del mercado y sobre la posición del precio respecto de algún parámetro (resistencia, fibo, etc...)
#
# Las variables que definen el estado del mercado son las siguientes:
#
# * FUZ_BOLLINGER_WIDTH_Gx: indican volatilidad relativa ya que da información de la anchura de las bandas respecto de los últimos 50 periodos.
# * FUZ_BOLLINGER_b_Gx: indica la posición del precio en las bandas. Indica estados de sobrecompra-sobreventa
# * FUZ_BULLISH_TREND_Gx/FUZ_BEARISH_TREND_Gx: indican la fortaleza de la tendencia bullish o bearish
# * FUZ_TREND_STRENGTH_Gx: indica la fortaleza de la tendencia actual, sea cual sea
# * FUZ_BULL_DIV_STRENGTH_Gx/FUZ_BEAR_DIV_STRENGTH_Gx: indica la fortaleza de las divergencias actuales
# * FUZ_TKLND_WDOW_Gx: indica la hora actual relativa a la ventana Tokio-Londres
# * FUZ_LNDNY_WDOW_Gx: indica la hora actual relativa a la ventana Londres-NY
# * FUZ_MKTOPEN_WDOW_Gx: indica la hora actual relativa a la apertura del mercado
# * FUZ_MKTCLOSE_WDOW_Gx: indica la hora actual relativa al cierre del mercado
#
# Las variables que definen la posición del precio son éstas otras:
#
# * FUZ_SMA_SLOW_DISTANCE_Gx: cercanía del precio a la SMA lenta
# * FUZ_SMA_MID_DISTANCE_Gx: cercanía del precio a la SMA media
# * FUZ_SMA_FAST_DISTANCE_Gx: cercanía del precio a la SMA rápida
# * FUZ_FIBO_xxx_Gx: cercanía del precio a diferentes niveles FIBO
# * FUZ_FIBO_RETR_Gx: cercanía del precio al retroceso fibo más cercano al precio
# * FUZ_FIBO_EXTN_Gx: cercanía del precio a la extensión fibo más cercana al precio
# * FUZ_SR_DISTANCE_Gx: cercanía del precio a un nivel Resistencia-Soporte relevante
# * FUZ_CHHI_DISTANCE_Gx: cercanía del precio a la parte superior de un canal
# * FUZ_CHLO_DISTANCE_Gx: cercanía del precio a la parte inferior de un canal

# %%
# list FUZ_.. variables
# market state selection mask
sel_mkt_mask = ['FUZ_BOLLINGER_WIDTH',
                'FUZ_BOLLINGER_b',
                'FUZ_BULLISH_TREND',
                'FUZ_BEARISH_TREND',
                'FUZ_BULL_DIV_STRENGTH',
                'FUZ_BEAR_DIV_STRENGTH',
                'FUX_TKLND_WDOW',
                'FUX_LNDNY_WDOW',
                'FUX_MKTOPEN_WDOW',
                'FUX_MKTCLOSE_WDOW']

# price position selection mask
sel_price_mask = ['FUZ_SMA_SLOW_DISTANCE',
                  'FUZ_SMA_MID_DISTANCE',
                  'FUZ_SMA_FAST_DISTANCE',
                  'FUZ_FIBO_',
                  'FUZ_SR_DISTANCE',
                  'FUZ_CHHI_DISTANCE',
                  'FUZ_CHLO_DISTANCE']

inp_vars = []
out_vars = []
for c in items['EURUSD']['df_filtered'].columns:
  for mm in sel_mkt_mask:
    if mm in c and '_G' in c[-5:]:
      inp_vars.append(c)      
  for pp in sel_price_mask:
    if pp in c and '_G' in c[-5:]:
      inp_vars.append(c)
      if 'h1_' in c[0:4]:
        out_vars.append(c)
      
print('inp_vars = {}'.format(inp_vars))
print('+++++++++++++++++++++++++++++++++++++')
print('out_vars = {}'.format(out_vars))
# Out:
# inp_vars = ['h1_FUZ_BOLLINGER_WIDTH_G0', 'h1_FUZ_BOLLINGER_WIDTH_G1', 'h1_FUZ_BOLLINGER_WIDTH_G2', 'h1_FUZ_BOLLINGER_WIDTH_G3', 'h1_FUZ_BOLLINGER_WIDTH_G4', 'h1_FUZ_BOLLINGER_WIDTH_G5', 'h1_FUZ_BOLLINGER_WIDTH_G6', 'h1_FUZ_BOLLINGER_b_G0', 'h1_FUZ_BOLLINGER_b_G1', 'h1_FUZ_BOLLINGER_b_G2', 'h1_FUZ_BOLLINGER_b_G3', 'h1_FUZ_BOLLINGER_b_G4', 'h1_FUZ_BOLLINGER_b_G5', 'h1_FUZ_BOLLINGER_b_G6', 'h1_FUZ_SMA_SLOW_DISTANCE_G0', 'h1_FUZ_SMA_SLOW_DISTANCE_G1', 'h1_FUZ_SMA_SLOW_DISTANCE_G2', 'h1_FUZ_SMA_SLOW_DISTANCE_G3', 'h1_FUZ_SMA_SLOW_DISTANCE_G4', 'h1_FUZ_SMA_MID_DISTANCE_G0', 'h1_FUZ_SMA_MID_DISTANCE_G1', 'h1_FUZ_SMA_MID_DISTANCE_G2', 'h1_FUZ_SMA_MID_DISTANCE_G3', 'h1_FUZ_SMA_MID_DISTANCE_G4', 'h1_FUZ_SMA_FAST_DISTANCE_G0', 'h1_FUZ_SMA_FAST_DISTANCE_G1', 'h1_FUZ_SMA_FAST_DISTANCE_G2', 'h1_FUZ_SMA_FAST_DISTANCE_G3', 'h1_FUZ_SMA_FAST_DISTANCE_G4', 'h1_FUZ_FIBO_023_G0', 'h1_FUZ_FIBO_023_G1', 'h1_FUZ_FIBO_023_G2', 'h1_FUZ_FIBO_023_G3', 'h1_FUZ_FIBO_023_G4', 'h1_FUZ_FIBO_038_G0', 'h1_FUZ_FIBO_038_G1', 'h1_FUZ_FIBO_038_G2', 'h1_FUZ_FIBO_038_G3', 'h1_FUZ_FIBO_038_G4', 'h1_FUZ_FIBO_050_G0', 'h1_FUZ_FIBO_050_G1', 'h1_FUZ_FIBO_050_G2', 'h1_FUZ_FIBO_050_G3', 'h1_FUZ_FIBO_050_G4', 'h1_FUZ_FIBO_061_G0', 'h1_FUZ_FIBO_061_G1', 'h1_FUZ_FIBO_061_G2', 'h1_FUZ_FIBO_061_G3', 'h1_FUZ_FIBO_061_G4', 'h1_FUZ_FIBO_078_G0', 'h1_FUZ_FIBO_078_G1', 'h1_FUZ_FIBO_078_G2', 'h1_FUZ_FIBO_078_G3', 'h1_FUZ_FIBO_078_G4', 'h1_FUZ_FIBO_RETR_G0', 'h1_FUZ_FIBO_RETR_G1', 'h1_FUZ_FIBO_RETR_G2', 'h1_FUZ_FIBO_RETR_G3', 'h1_FUZ_FIBO_RETR_G4', 'h1_FUZ_FIBO_123_G0', 'h1_FUZ_FIBO_123_G1', 'h1_FUZ_FIBO_123_G2', 'h1_FUZ_FIBO_123_G3', 'h1_FUZ_FIBO_123_G4', 'h1_FUZ_FIBO_138_G0', 'h1_FUZ_FIBO_138_G1', 'h1_FUZ_FIBO_138_G2', 'h1_FUZ_FIBO_138_G3', 'h1_FUZ_FIBO_138_G4', 'h1_FUZ_FIBO_150_G0', 'h1_FUZ_FIBO_150_G1', 'h1_FUZ_FIBO_150_G2', 'h1_FUZ_FIBO_150_G3', 'h1_FUZ_FIBO_150_G4', 'h1_FUZ_FIBO_161_G0', 'h1_FUZ_FIBO_161_G1', 'h1_FUZ_FIBO_161_G2', 'h1_FUZ_FIBO_161_G3', 'h1_FUZ_FIBO_161_G4', 'h1_FUZ_FIBO_178_G0', 'h1_FUZ_FIBO_178_G1', 'h1_FUZ_FIBO_178_G2', 'h1_FUZ_FIBO_178_G3', 'h1_FUZ_FIBO_178_G4', 'h1_FUZ_FIBO_EXTN_G0', 'h1_FUZ_FIBO_EXTN_G1', 'h1_FUZ_FIBO_EXTN_G2', 'h1_FUZ_FIBO_EXTN_G3', 'h1_FUZ_FIBO_EXTN_G4', 'h1_FUZ_SR_DISTANCE_G0', 'h1_FUZ_SR_DISTANCE_G1', 'h1_FUZ_SR_DISTANCE_G2', 'h1_FUZ_SR_DISTANCE_G3', 'h1_FUZ_SR_DISTANCE_G4', 'h1_FUZ_CHHI_DISTANCE_G0', 'h1_FUZ_CHHI_DISTANCE_G1', 'h1_FUZ_CHHI_DISTANCE_G2', 'h1_FUZ_CHHI_DISTANCE_G3', 'h1_FUZ_CHHI_DISTANCE_G4', 'h1_FUZ_CHLO_DISTANCE_G0', 'h1_FUZ_CHLO_DISTANCE_G1', 'h1_FUZ_CHLO_DISTANCE_G2', 'h1_FUZ_CHLO_DISTANCE_G3', 'h1_FUZ_CHLO_DISTANCE_G4', 'h1_FUZ_BULL_DIV_STRENGTH_G0', 'h1_FUZ_BULL_DIV_STRENGTH_G1', 'h1_FUZ_BULL_DIV_STRENGTH_G2', 'h1_FUZ_BEAR_DIV_STRENGTH_G0', 'h1_FUZ_BEAR_DIV_STRENGTH_G1', 'h1_FUZ_BEAR_DIV_STRENGTH_G2', 'h4_FUZ_BOLLINGER_WIDTH_G0', 'h4_FUZ_BOLLINGER_WIDTH_G1', 'h4_FUZ_BOLLINGER_WIDTH_G2', 'h4_FUZ_BOLLINGER_WIDTH_G3', 'h4_FUZ_BOLLINGER_WIDTH_G4', 'h4_FUZ_BOLLINGER_WIDTH_G5', 'h4_FUZ_BOLLINGER_WIDTH_G6', 'h4_FUZ_BOLLINGER_b_G0', 'h4_FUZ_BOLLINGER_b_G1', 'h4_FUZ_BOLLINGER_b_G2', 'h4_FUZ_BOLLINGER_b_G3', 'h4_FUZ_BOLLINGER_b_G4', 'h4_FUZ_BOLLINGER_b_G5', 'h4_FUZ_BOLLINGER_b_G6', 'h4_FUZ_SMA_SLOW_DISTANCE_G0', 'h4_FUZ_SMA_SLOW_DISTANCE_G1', 'h4_FUZ_SMA_SLOW_DISTANCE_G2', 'h4_FUZ_SMA_SLOW_DISTANCE_G3', 'h4_FUZ_SMA_SLOW_DISTANCE_G4', 'h4_FUZ_SMA_MID_DISTANCE_G0', 'h4_FUZ_SMA_MID_DISTANCE_G1', 'h4_FUZ_SMA_MID_DISTANCE_G2', 'h4_FUZ_SMA_MID_DISTANCE_G3', 'h4_FUZ_SMA_MID_DISTANCE_G4', 'h4_FUZ_SMA_FAST_DISTANCE_G0', 'h4_FUZ_SMA_FAST_DISTANCE_G1', 'h4_FUZ_SMA_FAST_DISTANCE_G2', 'h4_FUZ_SMA_FAST_DISTANCE_G3', 'h4_FUZ_SMA_FAST_DISTANCE_G4', 'h4_FUZ_FIBO_023_G0', 'h4_FUZ_FIBO_023_G1', 'h4_FUZ_FIBO_023_G2', 'h4_FUZ_FIBO_023_G3', 'h4_FUZ_FIBO_023_G4', 'h4_FUZ_FIBO_038_G0', 'h4_FUZ_FIBO_038_G1', 'h4_FUZ_FIBO_038_G2', 'h4_FUZ_FIBO_038_G3', 'h4_FUZ_FIBO_038_G4', 'h4_FUZ_FIBO_050_G0', 'h4_FUZ_FIBO_050_G1', 'h4_FUZ_FIBO_050_G2', 'h4_FUZ_FIBO_050_G3', 'h4_FUZ_FIBO_050_G4', 'h4_FUZ_FIBO_061_G0', 'h4_FUZ_FIBO_061_G1', 'h4_FUZ_FIBO_061_G2', 'h4_F ...
# +++++++++++++++++++++++++++++++++++++
# out_vars = ['h1_FUZ_SMA_SLOW_DISTANCE_G0', 'h1_FUZ_SMA_SLOW_DISTANCE_G1', 'h1_FUZ_SMA_SLOW_DISTANCE_G2', 'h1_FUZ_SMA_SLOW_DISTANCE_G3', 'h1_FUZ_SMA_SLOW_DISTANCE_G4', 'h1_FUZ_SMA_MID_DISTANCE_G0', 'h1_FUZ_SMA_MID_DISTANCE_G1', 'h1_FUZ_SMA_MID_DISTANCE_G2', 'h1_FUZ_SMA_MID_DISTANCE_G3', 'h1_FUZ_SMA_MID_DISTANCE_G4', 'h1_FUZ_SMA_FAST_DISTANCE_G0', 'h1_FUZ_SMA_FAST_DISTANCE_G1', 'h1_FUZ_SMA_FAST_DISTANCE_G2', 'h1_FUZ_SMA_FAST_DISTANCE_G3', 'h1_FUZ_SMA_FAST_DISTANCE_G4', 'h1_FUZ_FIBO_023_G0', 'h1_FUZ_FIBO_023_G1', 'h1_FUZ_FIBO_023_G2', 'h1_FUZ_FIBO_023_G3', 'h1_FUZ_FIBO_023_G4', 'h1_FUZ_FIBO_038_G0', 'h1_FUZ_FIBO_038_G1', 'h1_FUZ_FIBO_038_G2', 'h1_FUZ_FIBO_038_G3', 'h1_FUZ_FIBO_038_G4', 'h1_FUZ_FIBO_050_G0', 'h1_FUZ_FIBO_050_G1', 'h1_FUZ_FIBO_050_G2', 'h1_FUZ_FIBO_050_G3', 'h1_FUZ_FIBO_050_G4', 'h1_FUZ_FIBO_061_G0', 'h1_FUZ_FIBO_061_G1', 'h1_FUZ_FIBO_061_G2', 'h1_FUZ_FIBO_061_G3', 'h1_FUZ_FIBO_061_G4', 'h1_FUZ_FIBO_078_G0', 'h1_FUZ_FIBO_078_G1', 'h1_FUZ_FIBO_078_G2', 'h1_FUZ_FIBO_078_G3', 'h1_FUZ_FIBO_078_G4', 'h1_FUZ_FIBO_RETR_G0', 'h1_FUZ_FIBO_RETR_G1', 'h1_FUZ_FIBO_RETR_G2', 'h1_FUZ_FIBO_RETR_G3', 'h1_FUZ_FIBO_RETR_G4', 'h1_FUZ_FIBO_123_G0', 'h1_FUZ_FIBO_123_G1', 'h1_FUZ_FIBO_123_G2', 'h1_FUZ_FIBO_123_G3', 'h1_FUZ_FIBO_123_G4', 'h1_FUZ_FIBO_138_G0', 'h1_FUZ_FIBO_138_G1', 'h1_FUZ_FIBO_138_G2', 'h1_FUZ_FIBO_138_G3', 'h1_FUZ_FIBO_138_G4', 'h1_FUZ_FIBO_150_G0', 'h1_FUZ_FIBO_150_G1', 'h1_FUZ_FIBO_150_G2', 'h1_FUZ_FIBO_150_G3', 'h1_FUZ_FIBO_150_G4', 'h1_FUZ_FIBO_161_G0', 'h1_FUZ_FIBO_161_G1', 'h1_FUZ_FIBO_161_G2', 'h1_FUZ_FIBO_161_G3', 'h1_FUZ_FIBO_161_G4', 'h1_FUZ_FIBO_178_G0', 'h1_FUZ_FIBO_178_G1', 'h1_FUZ_FIBO_178_G2', 'h1_FUZ_FIBO_178_G3', 'h1_FUZ_FIBO_178_G4', 'h1_FUZ_FIBO_EXTN_G0', 'h1_FUZ_FIBO_EXTN_G1', 'h1_FUZ_FIBO_EXTN_G2', 'h1_FUZ_FIBO_EXTN_G3', 'h1_FUZ_FIBO_EXTN_G4', 'h1_FUZ_SR_DISTANCE_G0', 'h1_FUZ_SR_DISTANCE_G1', 'h1_FUZ_SR_DISTANCE_G2', 'h1_FUZ_SR_DISTANCE_G3', 'h1_FUZ_SR_DISTANCE_G4', 'h1_FUZ_CHHI_DISTANCE_G0', 'h1_FUZ_CHHI_DISTANCE_G1', 'h1_FUZ_CHHI_DISTANCE_G2', 'h1_FUZ_CHHI_DISTANCE_G3', 'h1_FUZ_CHHI_DISTANCE_G4', 'h1_FUZ_CHLO_DISTANCE_G0', 'h1_FUZ_CHLO_DISTANCE_G1', 'h1_FUZ_CHLO_DISTANCE_G2', 'h1_FUZ_CHLO_DISTANCE_G3', 'h1_FUZ_CHLO_DISTANCE_G4']

# %%
# rename columns as inp_xxxx or out_xxx and concatenate them
for symbol in items.keys():
  df = items[symbol]['df_filtered']
  for i in inp_vars:
    df['inp_{}'.format(i)] = df[i]
  for o in out_vars:
    df['out_{}'.format(o)] = df[o]  

  # drop all columns doesn't start with inp_ or out_
  drop_cols = []
  for c in df.columns:
    if c[0:4] != 'inp_' and c[0:4] != 'out_':
      drop_cols.append(c)

  df.drop(columns=drop_cols, inplace=True)
  print('New Cols in {} = {}'.format(symbol, df.columns))
# Out:
# New Cols in AUDUSD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURAUD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURCAD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURCHF = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURGBP = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURJPY = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURNZD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in EURUSD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in GBPCAD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in GBPJPY = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in GBPUSD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in NZDUSD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in USDCAD = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in USDCHF = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)
# New Cols in USDJPY = Index(['inp_h1_FUZ_BOLLINGER_WIDTH_G0', 'inp_h1_FUZ_BOLLINGER_WIDTH_G1',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G2', 'inp_h1_FUZ_BOLLINGER_WIDTH_G3',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G4', 'inp_h1_FUZ_BOLLINGER_WIDTH_G5',
#        'inp_h1_FUZ_BOLLINGER_WIDTH_G6', 'inp_h1_FUZ_BOLLINGER_b_G0',
#        'inp_h1_FUZ_BOLLINGER_b_G1', 'inp_h1_FUZ_BOLLINGER_b_G2',
#        ...
#        'out_h1_FUZ_CHHI_DISTANCE_G0', 'out_h1_FUZ_CHHI_DISTANCE_G1',
#        'out_h1_FUZ_CHHI_DISTANCE_G2', 'out_h1_FUZ_CHHI_DISTANCE_G3',
#        'out_h1_FUZ_CHHI_DISTANCE_G4', 'out_h1_FUZ_CHLO_DISTANCE_G0',
#        'out_h1_FUZ_CHLO_DISTANCE_G1', 'out_h1_FUZ_CHLO_DISTANCE_G2',
#        'out_h1_FUZ_CHLO_DISTANCE_G3', 'out_h1_FUZ_CHLO_DISTANCE_G4'],
#       dtype='object', length=420)

# %% [markdown]
# #### Guardo filtered dataframes

# %%
# save dataframes in filtered folder
path = '../csv_data/indicators/fuzzified/merged/filtered'
for symbol in items.keys():
  items[symbol]['df_filtered'].to_csv('{}/{}_flips.csv'.format(path, symbol), sep=';')
  print('Saved file {}'.format('{}/{}_flips.csv'.format(path, symbol)))
  print('+++++++++++++++++++++++++++++++++++++')
# Out:
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/AUDUSD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURAUD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURCAD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURCHF_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURGBP_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURJPY_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURNZD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/EURUSD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/GBPCAD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/GBPJPY_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/GBPUSD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/NZDUSD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/USDCAD_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/USDCHF_flips.csv
# +++++++++++++++++++++++++++++++++++++
# Saved file ../csv_data/indicators/fuzzified/merged/filtered/USDJPY_flips.csv
# +++++++++++++++++++++++++++++++++++++

# %% [markdown]
# #### Conversión a pares de entrenamiento supervisado con loopback=6 y prediction = 2

# %%
# build supervised dataframes
for symbol in items.keys():
  num_inputs = 0
  num_outputs = 0
  for c in items[symbol]['df_filtered']:
    if 'inp_' in c:
      num_inputs += 1
    if 'out_' in c:
      num_outputs += 1      
  print('Processing {} with shape {}, num_inputs={}, num_outputs={}'.format(symbol, items[symbol]['df_filtered'].shape, num_inputs, num_outputs))
  items[symbol]['df_supervised'] = MyUtils.series_to_supervised(items[symbol]['df_filtered'], num_inputs=num_inputs, num_outputs=num_outputs, n_in=6, n_out=2, dropnan=False)
  print('Built supervised dataframe with shape {}'.format(items[symbol]['df_supervised'].shape))
  print('+++++++++++++++++++++++++++++++++++++')
# Out:
# Processing AUDUSD with shape (423, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (423, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURAUD with shape (398, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (398, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURCAD with shape (367, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (367, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURCHF with shape (369, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (369, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURGBP with shape (382, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (382, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURJPY with shape (402, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (402, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURNZD with shape (330, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (330, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing EURUSD with shape (359, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (359, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing GBPCAD with shape (307, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (307, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing GBPJPY with shape (421, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (421, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing GBPUSD with shape (380, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (380, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing NZDUSD with shape (417, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (417, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing USDCAD with shape (350, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (350, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing USDCHF with shape (379, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (379, 2160)
# +++++++++++++++++++++++++++++++++++++
# Processing USDJPY with shape (410, 420), num_inputs=330, num_outputs=90
# Built supervised dataframe with shape (410, 2160)
# +++++++++++++++++++++++++++++++++++++

# %%
for c in items['EURUSD']['df_supervised'].columns:
  print('col={}, value={}'.format(c, items['EURUSD']['df_supervised'][c].iloc[40]))
# Out:
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G0(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G1(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G2(t-5), value=0.6183859386768831
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G3(t-5), value=0.38161406132311704
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G4(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G5(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G6(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G0(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G1(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G2(t-5), value=0.06686432544939093
# col=inp_h1_FUZ_BOLLINGER_b_G3(t-5), value=0.9331356745506092
# col=inp_h1_FUZ_BOLLINGER_b_G4(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G5(t-5), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G6(t-5), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G0(t-5), value=0.9465278912189484
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G1(t-5), value=0.05347210878105153
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G2(t-5), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G0(t-5), value=1.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G1(t-5), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G2(t-5), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G0(t-5), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G1(t-5), value=0.9462275045524392
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G2(t-5), value=0.0537724954475607
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_023_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_023_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_023_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_023_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_023_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_038_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_038_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_038_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_038_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_038_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_050_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_050_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_050_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_050_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_050_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_061_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_061_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_061_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_061_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_061_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_078_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_078_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_078_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_078_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_078_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_RETR_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_123_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_123_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_123_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_123_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_123_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_138_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_138_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_138_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_138_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_138_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_150_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_150_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_150_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_150_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_150_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_161_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_161_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_161_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_161_G3(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_161_G4(t-5), value=1.0
# col=inp_h1_FUZ_FIBO_178_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_178_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_178_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_178_G3(t-5), value=1.4155343563970746e-13
# col=inp_h1_FUZ_FIBO_178_G4(t-5), value=0.9999999999998584
# col=inp_h1_FUZ_FIBO_EXTN_G0(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G1(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G2(t-5), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G3(t-5), value=1.4155343563970746e-13
# col=inp_h1_FUZ_FIBO_EXTN_G4(t-5), value=0.9999999999998584
# col=inp_h1_FUZ_SR_DISTANCE_G0(t-5), value=1.0
# col=inp_h1_FUZ_SR_DISTANCE_G1(t-5), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G2(t-5), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G0(t-5), value=1.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G1(t-5), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G2(t-5), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G0(t-5), value=1.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G1(t-5), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G2(t-5), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G3(t-5), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G4(t-5), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G0(t-5), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G2(t-5), value=1.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G0(t-5), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G2(t-5), value=1.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G0(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G1(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G2(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G3(t-5), value=0.5877516466297532
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G4(t-5), value=0.4122483533702467
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G5(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G6(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G0(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G1(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G2(t-5), value=0.5221467477207077
# col=inp_h4_FUZ_BOLLINGER_b_G3(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G4(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G5(t-5), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G6(t-5), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G0(t-5), value=1.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G1(t-5), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G3(t-5), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G4(t-5), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G0(t-5), value=1.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G1(t-5), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G3(t-5), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G4(t-5), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G0(t-5), value=0.933612248585027
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G1(t-5), value=0.06638775141497298
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G3(t-5), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G4(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_023_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_023_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_023_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_023_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_023_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_038_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_038_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_038_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_038_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_038_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_050_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_050_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_050_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_050_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_050_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_061_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_061_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_061_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_061_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_061_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_078_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_078_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_078_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_078_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_078_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_RETR_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_123_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_123_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_123_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_123_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_123_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_138_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_138_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_138_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_138_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_138_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_150_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_150_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_150_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_150_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_150_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_161_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_161_G1(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_161_G2(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_161_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_161_G4(t-5), value=1.0
# col=inp_h4_FUZ_FIBO_178_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_178_G1(t-5), value=0.9181879648411464
# col=inp_h4_FUZ_FIBO_178_G2(t-5), value=0.0818120351588537
# col=inp_h4_FUZ_FIBO_178_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_178_G4(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G0(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G1(t-5), value=0.9181879648411464
# col=inp_h4_FUZ_FIBO_EXTN_G2(t-5), value=0.0818120351588537
# col=inp_h4_FUZ_FIBO_EXTN_G3(t-5), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G4(t-5), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G0(t-5), value=1.0
# col=inp_h4_FUZ_SR_DISTANCE_G1(t-5), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G3(t-5), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G4(t-5), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G0(t-5), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G1(t-5), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G3(t-5), value=0.8484990871392719
# col=inp_h4_FUZ_CHHI_DISTANCE_G4(t-5), value=0.15150091286072795
# col=inp_h4_FUZ_CHLO_DISTANCE_G0(t-5), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G1(t-5), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G2(t-5), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G3(t-5), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G4(t-5), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G0(t-5), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G2(t-5), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G0(t-5), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G2(t-5), value=1.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G0(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G1(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G2(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G3(t-5), value=0.33946085524310465
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G4(t-5), value=0.6605391447568953
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G5(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G6(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G0(t-5), value=0.5097023225348037
# col=inp_d1_FUZ_BOLLINGER_b_G1(t-5), value=0.4902976774651962
# col=inp_d1_FUZ_BOLLINGER_b_G2(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G3(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G4(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G5(t-5), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G6(t-5), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G0(t-5), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G1(t-5), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G3(t-5), value=0.8772338734868415
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G4(t-5), value=0.12276612651315855
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G0(t-5), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G1(t-5), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G3(t-5), value=0.9389743908255276
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G4(t-5), value=0.061025609174472376
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G0(t-5), value=1.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G1(t-5), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G3(t-5), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_023_G0(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_023_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_023_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_023_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_023_G4(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_038_G0(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_038_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_038_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_038_G3(t-5), value=0.2518187487009144
# col=inp_d1_FUZ_FIBO_038_G4(t-5), value=0.7481812512990856
# col=inp_d1_FUZ_FIBO_050_G0(t-5), value=0.2518187487009144
# col=inp_d1_FUZ_FIBO_050_G1(t-5), value=0.7481812512990856
# col=inp_d1_FUZ_FIBO_050_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_050_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_050_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_061_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_061_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_061_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_061_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_061_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_078_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_078_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_078_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_078_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_078_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G0(t-5), value=0.2518187487009144
# col=inp_d1_FUZ_FIBO_RETR_G1(t-5), value=0.7481812512990856
# col=inp_d1_FUZ_FIBO_RETR_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_123_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_123_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_123_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_123_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_123_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_138_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_138_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_138_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_138_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_138_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_150_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_150_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_150_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_150_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_150_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_161_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_161_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_161_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_161_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_161_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_178_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_178_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_178_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_178_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_178_G4(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G0(t-5), value=1.0
# col=inp_d1_FUZ_FIBO_EXTN_G1(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G2(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G3(t-5), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G4(t-5), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G0(t-5), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G1(t-5), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G3(t-5), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G4(t-5), value=1.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G0(t-5), value=0.4720004806728502
# col=inp_d1_FUZ_CHHI_DISTANCE_G1(t-5), value=0.5279995193271498
# col=inp_d1_FUZ_CHHI_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G3(t-5), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G4(t-5), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G0(t-5), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G1(t-5), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G2(t-5), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G3(t-5), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G4(t-5), value=1.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G0(t-5), value=1.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G2(t-5), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G0(t-5), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G1(t-5), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G2(t-5), value=1.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G0(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G1(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G2(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G3(t-4), value=0.8437761643478674
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G4(t-4), value=0.15622383565213266
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G5(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G6(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G0(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G1(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G2(t-4), value=0.4606038326404372
# col=inp_h1_FUZ_BOLLINGER_b_G3(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G4(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G5(t-4), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G6(t-4), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_023_G0(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_023_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_023_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_023_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_023_G4(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_038_G0(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_038_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_038_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_038_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_038_G4(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_050_G0(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_050_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_050_G2(t-4), value=0.7390169638973026
# col=inp_h1_FUZ_FIBO_050_G3(t-4), value=0.2609830361026973
# col=inp_h1_FUZ_FIBO_050_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_061_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_061_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_061_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_061_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_061_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_078_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_078_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_078_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_078_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_078_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G0(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G2(t-4), value=0.7390169638973026
# col=inp_h1_FUZ_FIBO_RETR_G3(t-4), value=0.2609830361026973
# col=inp_h1_FUZ_FIBO_RETR_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_123_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_123_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_123_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_123_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_123_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_138_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_138_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_138_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_138_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_138_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_150_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_150_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_150_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_150_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_150_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_161_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_161_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_161_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_161_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_161_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_178_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_178_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_178_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_178_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_178_G4(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G0(t-4), value=1.0
# col=inp_h1_FUZ_FIBO_EXTN_G1(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G2(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G3(t-4), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G4(t-4), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_SR_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G0(t-4), value=1.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G1(t-4), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G2(t-4), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G3(t-4), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G4(t-4), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G0(t-4), value=1.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G1(t-4), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G2(t-4), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G0(t-4), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G1(t-4), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G2(t-4), value=1.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G0(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G1(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G2(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G3(t-4), value=0.25789746949960124
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G4(t-4), value=0.7421025305003988
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G5(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G6(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G0(t-4), value=0.024534498584773638
# col=inp_h4_FUZ_BOLLINGER_b_G1(t-4), value=0.9754655014152264
# col=inp_h4_FUZ_BOLLINGER_b_G2(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G3(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G4(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G5(t-4), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G6(t-4), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_023_G0(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_023_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_023_G2(t-4), value=0.3877156490884436
# col=inp_h4_FUZ_FIBO_023_G3(t-4), value=0.6122843509115564
# col=inp_h4_FUZ_FIBO_023_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_038_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_038_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_038_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_038_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_038_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_050_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_050_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_050_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_050_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_050_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_061_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_061_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_061_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_061_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_061_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_078_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_078_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_078_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_078_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_078_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G0(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G2(t-4), value=0.3877156490884436
# col=inp_h4_FUZ_FIBO_RETR_G3(t-4), value=0.6122843509115564
# col=inp_h4_FUZ_FIBO_RETR_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_123_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_123_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_123_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_123_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_123_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_138_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_138_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_138_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_138_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_138_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_150_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_150_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_150_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_150_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_150_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_161_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_161_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_161_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_161_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_161_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_178_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_178_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_178_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_178_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_178_G4(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G0(t-4), value=1.0
# col=inp_h4_FUZ_FIBO_EXTN_G1(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G2(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G3(t-4), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G4(t-4), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_SR_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G0(t-4), value=1.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G1(t-4), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G2(t-4), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G3(t-4), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G4(t-4), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G0(t-4), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G1(t-4), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G2(t-4), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G0(t-4), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G1(t-4), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G2(t-4), value=1.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G0(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G1(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G2(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G3(t-4), value=0.01289314063725866
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G4(t-4), value=0.9871068593627412
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G5(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G6(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G0(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G1(t-4), value=0.9998308579524909
# col=inp_d1_FUZ_BOLLINGER_b_G2(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G3(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G4(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G5(t-4), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G6(t-4), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G0(t-4), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G1(t-4), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G2(t-4), value=0.9623666188140046
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G3(t-4), value=0.037633381185995365
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G4(t-4), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G0(t-4), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G1(t-4), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G2(t-4), value=0.9723013369046984
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G3(t-4), value=0.027698663095301532
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G4(t-4), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G0(t-4), value=1.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G1(t-4), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G2(t-4), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G3(t-4), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_023_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_023_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_023_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_023_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_023_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_038_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_038_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_038_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_038_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_038_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_050_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_050_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_050_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_050_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_050_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_061_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_061_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_061_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_061_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_061_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_078_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_078_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_078_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_078_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_078_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_RETR_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_123_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_123_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_123_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_123_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_123_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_138_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_138_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_138_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_138_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_138_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_150_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_150_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_150_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_150_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_150_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_161_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_161_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_161_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_161_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_161_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_178_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_178_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_178_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_178_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_178_G4(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G0(t-4), value=1.0
# col=inp_d1_FUZ_FIBO_EXTN_G1(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G2(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G3(t-4), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G4(t-4), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G0(t-4), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G1(t-4), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G2(t-4), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G3(t-4), value=0.8459163474157616
# col=inp_d1_FUZ_SR_DISTANCE_G4(t-4), value=0.15408365258423834
# col=inp_d1_FUZ_CHHI_DISTANCE_G0(t-4), value=0.4720004806728502
# col=inp_d1_FUZ_CHHI_DISTANCE_G1(t-4), value=0.5279995193271498
# col=inp_d1_FUZ_CHHI_DISTANCE_G2(t-4), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G3(t-4), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G4(t-4), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G0(t-4), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G1(t-4), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G2(t-4), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G3(t-4), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G4(t-4), value=1.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G0(t-4), value=0.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G1(t-4), value=0.8
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G2(t-4), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G0(t-4), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G1(t-4), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G2(t-4), value=1.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G0(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G1(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G2(t-3), value=0.9347323912081916
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G3(t-3), value=0.06526760879180836
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G4(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G5(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G6(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G0(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G1(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G2(t-3), value=0.8472812381346013
# col=inp_h1_FUZ_BOLLINGER_b_G3(t-3), value=0.15271876186539873
# col=inp_h1_FUZ_BOLLINGER_b_G4(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G5(t-3), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G6(t-3), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G0(t-3), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G1(t-3), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G3(t-3), value=0.0989938052486159
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G4(t-3), value=0.901006194751384
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G0(t-3), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G1(t-3), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G3(t-3), value=0.515372159842417
# col=inp_h1_FUZ_SMA_MID_DISTANCE_G4(t-3), value=0.484627840157583
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G0(t-3), value=0.3247011487674229
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G1(t-3), value=0.6752988512325769
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G3(t-3), value=0.0
# col=inp_h1_FUZ_SMA_FAST_DISTANCE_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_023_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_023_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_023_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_023_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_023_G4(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_038_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_038_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_038_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_038_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_038_G4(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_050_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_050_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_050_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_050_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_050_G4(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_061_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_061_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_061_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_061_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_061_G4(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_078_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_078_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_078_G2(t-3), value=0.07329842931899799
# col=inp_h1_FUZ_FIBO_078_G3(t-3), value=0.9267015706810021
# col=inp_h1_FUZ_FIBO_078_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G0(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_RETR_G2(t-3), value=0.07329842931899799
# col=inp_h1_FUZ_FIBO_RETR_G3(t-3), value=0.9267015706810021
# col=inp_h1_FUZ_FIBO_RETR_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_123_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_123_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_123_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_123_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_123_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_138_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_138_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_138_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_138_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_138_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_150_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_150_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_150_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_150_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_150_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_161_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_161_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_161_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_161_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_161_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_178_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_178_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_178_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_178_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_178_G4(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G0(t-3), value=1.0
# col=inp_h1_FUZ_FIBO_EXTN_G1(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G2(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G3(t-3), value=0.0
# col=inp_h1_FUZ_FIBO_EXTN_G4(t-3), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G0(t-3), value=1.0
# col=inp_h1_FUZ_SR_DISTANCE_G1(t-3), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G3(t-3), value=0.0
# col=inp_h1_FUZ_SR_DISTANCE_G4(t-3), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G0(t-3), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G1(t-3), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G3(t-3), value=0.0
# col=inp_h1_FUZ_CHHI_DISTANCE_G4(t-3), value=1.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G0(t-3), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G1(t-3), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G2(t-3), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G3(t-3), value=0.0
# col=inp_h1_FUZ_CHLO_DISTANCE_G4(t-3), value=1.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G0(t-3), value=1.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G1(t-3), value=0.0
# col=inp_h1_FUZ_BULL_DIV_STRENGTH_G2(t-3), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G0(t-3), value=1.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G1(t-3), value=0.0
# col=inp_h1_FUZ_BEAR_DIV_STRENGTH_G2(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G0(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G1(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G2(t-3), value=0.19945594541531889
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G3(t-3), value=0.8005440545846811
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G4(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G5(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_WIDTH_G6(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G0(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G1(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G2(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G3(t-3), value=0.0
# col=inp_h4_FUZ_BOLLINGER_b_G4(t-3), value=0.4845546092393628
# col=inp_h4_FUZ_BOLLINGER_b_G5(t-3), value=0.5154453907606372
# col=inp_h4_FUZ_BOLLINGER_b_G6(t-3), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G0(t-3), value=0.6018578699697656
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G1(t-3), value=0.3981421300302344
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_SMA_SLOW_DISTANCE_G4(t-3), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G0(t-3), value=0.8493644815664453
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G1(t-3), value=0.15063551843355474
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_SMA_MID_DISTANCE_G4(t-3), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G0(t-3), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G1(t-3), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_SMA_FAST_DISTANCE_G4(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_023_G0(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_023_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_023_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_023_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_023_G4(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_038_G0(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_038_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_038_G2(t-3), value=0.8419987215000997
# col=inp_h4_FUZ_FIBO_038_G3(t-3), value=0.15800127849990028
# col=inp_h4_FUZ_FIBO_038_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_050_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_050_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_050_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_050_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_050_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_061_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_061_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_061_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_061_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_061_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_078_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_078_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_078_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_078_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_078_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G0(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G2(t-3), value=0.8419987215000997
# col=inp_h4_FUZ_FIBO_RETR_G3(t-3), value=0.15800127849990028
# col=inp_h4_FUZ_FIBO_RETR_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_123_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_123_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_123_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_123_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_123_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_138_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_138_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_138_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_138_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_138_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_150_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_150_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_150_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_150_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_150_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_161_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_161_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_161_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_161_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_161_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_178_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_178_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_178_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_178_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_178_G4(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G0(t-3), value=1.0
# col=inp_h4_FUZ_FIBO_EXTN_G1(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G2(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G3(t-3), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G4(t-3), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G0(t-3), value=1.0
# col=inp_h4_FUZ_SR_DISTANCE_G1(t-3), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G4(t-3), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G0(t-3), value=1.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G1(t-3), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G4(t-3), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G0(t-3), value=1.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G1(t-3), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G2(t-3), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G3(t-3), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G4(t-3), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G0(t-3), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G1(t-3), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G2(t-3), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G0(t-3), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G1(t-3), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G2(t-3), value=1.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G0(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G1(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G2(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G3(t-3), value=0.9701274835810594
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G4(t-3), value=0.029872516418940575
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G5(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G6(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G0(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G1(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G2(t-3), value=0.7465436657391623
# col=inp_d1_FUZ_BOLLINGER_b_G3(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G4(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G5(t-3), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G6(t-3), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G0(t-3), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G1(t-3), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G3(t-3), value=0.7980573392601563
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G4(t-3), value=0.20194266073984368
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G0(t-3), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G1(t-3), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G3(t-3), value=0.8794784715522129
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G4(t-3), value=0.12052152844778707
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G0(t-3), value=1.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G1(t-3), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G3(t-3), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_023_G0(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_023_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_023_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_023_G3(t-3), value=0.02115282113757111
# col=inp_d1_FUZ_FIBO_023_G4(t-3), value=0.9788471788624288
# col=inp_d1_FUZ_FIBO_038_G0(t-3), value=0.02115282113757111
# col=inp_d1_FUZ_FIBO_038_G1(t-3), value=0.9788471788624288
# col=inp_d1_FUZ_FIBO_038_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_038_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_038_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_050_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_050_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_050_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_050_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_050_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_061_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_061_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_061_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_061_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_061_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_078_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_078_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_078_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_078_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_078_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G0(t-3), value=0.02115282113757111
# col=inp_d1_FUZ_FIBO_RETR_G1(t-3), value=0.9788471788624288
# col=inp_d1_FUZ_FIBO_RETR_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_123_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_123_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_123_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_123_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_123_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_138_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_138_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_138_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_138_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_138_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_150_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_150_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_150_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_150_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_150_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_161_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_161_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_161_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_161_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_161_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_178_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_178_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_178_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_178_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_178_G4(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G0(t-3), value=1.0
# col=inp_d1_FUZ_FIBO_EXTN_G1(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G2(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G3(t-3), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G4(t-3), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G0(t-3), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G1(t-3), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G3(t-3), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G4(t-3), value=1.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G0(t-3), value=0.4720004806728502
# col=inp_d1_FUZ_CHHI_DISTANCE_G1(t-3), value=0.5279995193271498
# col=inp_d1_FUZ_CHHI_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G3(t-3), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G4(t-3), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G0(t-3), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G1(t-3), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G2(t-3), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G3(t-3), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G4(t-3), value=1.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G0(t-3), value=0.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G1(t-3), value=0.8
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G2(t-3), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G0(t-3), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G1(t-3), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G2(t-3), value=1.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G0(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G1(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G2(t-2), value=0.23313712580830426
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G3(t-2), value=0.7668628741916957
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G4(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G5(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_WIDTH_G6(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G0(t-2), value=0.23539216095775284
# col=inp_h1_FUZ_BOLLINGER_b_G1(t-2), value=0.7646078390422472
# col=inp_h1_FUZ_BOLLINGER_b_G2(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G3(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G4(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G5(t-2), value=0.0
# col=inp_h1_FUZ_BOLLINGER_b_G6(t-2), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G0(t-2), value=0.0
# col=inp_h1_FUZ_SMA_SLOW_DISTANCE_G1(t-2), value=0.0
# ...
# col=inp_h4_FUZ_FIBO_RETR_G0(t), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_RETR_G4(t), value=1.0
# col=inp_h4_FUZ_FIBO_123_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_123_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_123_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_123_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_123_G4(t), value=0.0
# col=inp_h4_FUZ_FIBO_138_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_138_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_138_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_138_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_138_G4(t), value=0.0
# col=inp_h4_FUZ_FIBO_150_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_150_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_150_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_150_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_150_G4(t), value=0.0
# col=inp_h4_FUZ_FIBO_161_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_161_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_161_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_161_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_161_G4(t), value=0.0
# col=inp_h4_FUZ_FIBO_178_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_178_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_178_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_178_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_178_G4(t), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G0(t), value=1.0
# col=inp_h4_FUZ_FIBO_EXTN_G1(t), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G2(t), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G3(t), value=0.0
# col=inp_h4_FUZ_FIBO_EXTN_G4(t), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G0(t), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G1(t), value=0.0
# col=inp_h4_FUZ_SR_DISTANCE_G2(t), value=0.9773089274485068
# col=inp_h4_FUZ_SR_DISTANCE_G3(t), value=0.022691072551493236
# col=inp_h4_FUZ_SR_DISTANCE_G4(t), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G0(t), value=0.3475293226889168
# col=inp_h4_FUZ_CHHI_DISTANCE_G1(t), value=0.6524706773110832
# col=inp_h4_FUZ_CHHI_DISTANCE_G2(t), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G3(t), value=0.0
# col=inp_h4_FUZ_CHHI_DISTANCE_G4(t), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G0(t), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G1(t), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G2(t), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G3(t), value=0.0
# col=inp_h4_FUZ_CHLO_DISTANCE_G4(t), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G0(t), value=1.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G1(t), value=0.0
# col=inp_h4_FUZ_BULL_DIV_STRENGTH_G2(t), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G0(t), value=1.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G1(t), value=0.0
# col=inp_h4_FUZ_BEAR_DIV_STRENGTH_G2(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G0(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G1(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G2(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G3(t), value=0.9686921650274232
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G4(t), value=0.03130783497257679
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G5(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_WIDTH_G6(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G0(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G1(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G2(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G3(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G4(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G5(t), value=0.0
# col=inp_d1_FUZ_BOLLINGER_b_G6(t), value=0.09731420026756496
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G0(t), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G1(t), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G3(t), value=0.2942269824293835
# col=inp_d1_FUZ_SMA_SLOW_DISTANCE_G4(t), value=0.7057730175706165
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G0(t), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G1(t), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G3(t), value=0.4645992734829545
# col=inp_d1_FUZ_SMA_MID_DISTANCE_G4(t), value=0.5354007265170455
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G0(t), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G1(t), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G3(t), value=0.650399748308511
# col=inp_d1_FUZ_SMA_FAST_DISTANCE_G4(t), value=0.349600251691489
# col=inp_d1_FUZ_FIBO_023_G0(t), value=0.0
# col=inp_d1_FUZ_FIBO_023_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_023_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_023_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_023_G4(t), value=1.0
# col=inp_d1_FUZ_FIBO_038_G0(t), value=0.0
# col=inp_d1_FUZ_FIBO_038_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_038_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_038_G3(t), value=0.9426254473463629
# col=inp_d1_FUZ_FIBO_038_G4(t), value=0.057374552653637015
# col=inp_d1_FUZ_FIBO_050_G0(t), value=0.9426254473463629
# col=inp_d1_FUZ_FIBO_050_G1(t), value=0.057374552653637015
# col=inp_d1_FUZ_FIBO_050_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_050_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_050_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_061_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_061_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_061_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_061_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_061_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_078_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_078_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_078_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_078_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_078_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G0(t), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_RETR_G3(t), value=0.9426254473463629
# col=inp_d1_FUZ_FIBO_RETR_G4(t), value=0.057374552653637015
# col=inp_d1_FUZ_FIBO_123_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_123_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_123_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_123_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_123_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_138_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_138_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_138_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_138_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_138_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_150_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_150_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_150_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_150_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_150_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_161_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_161_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_161_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_161_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_161_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_178_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_178_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_178_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_178_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_178_G4(t), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G0(t), value=1.0
# col=inp_d1_FUZ_FIBO_EXTN_G1(t), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G2(t), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G3(t), value=0.0
# col=inp_d1_FUZ_FIBO_EXTN_G4(t), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G0(t), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G1(t), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G3(t), value=0.0
# col=inp_d1_FUZ_SR_DISTANCE_G4(t), value=1.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G0(t), value=0.4720004806728502
# col=inp_d1_FUZ_CHHI_DISTANCE_G1(t), value=0.5279995193271498
# col=inp_d1_FUZ_CHHI_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G3(t), value=0.0
# col=inp_d1_FUZ_CHHI_DISTANCE_G4(t), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G0(t), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G1(t), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G2(t), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G3(t), value=0.0
# col=inp_d1_FUZ_CHLO_DISTANCE_G4(t), value=1.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G0(t), value=0.0
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G1(t), value=0.8
# col=inp_d1_FUZ_BULL_DIV_STRENGTH_G2(t), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G0(t), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G1(t), value=0.0
# col=inp_d1_FUZ_BEAR_DIV_STRENGTH_G2(t), value=1.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G3(t+1), value=0.28819980758671626
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G4(t+1), value=0.7118001924132837
# col=out_h1_FUZ_SMA_MID_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G3(t+1), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G4(t+1), value=1.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G3(t+1), value=0.7279022236598051
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G4(t+1), value=0.2720977763401951
# col=out_h1_FUZ_FIBO_023_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_023_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_023_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_023_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_023_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_038_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_038_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_038_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_038_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_038_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_050_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_050_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_050_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_050_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_050_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_061_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_061_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_061_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_061_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_061_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_078_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_078_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_078_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_078_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_078_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_RETR_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_123_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_123_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_123_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_123_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_123_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_138_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_138_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_138_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_138_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_138_G4(t+1), value=1.0
# col=out_h1_FUZ_FIBO_150_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_150_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_150_G2(t+1), value=0.5624063707319682
# col=out_h1_FUZ_FIBO_150_G3(t+1), value=0.4375936292680319
# col=out_h1_FUZ_FIBO_150_G4(t+1), value=0.0
# col=out_h1_FUZ_FIBO_161_G0(t+1), value=1.0
# col=out_h1_FUZ_FIBO_161_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_161_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_161_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_161_G4(t+1), value=0.0
# col=out_h1_FUZ_FIBO_178_G0(t+1), value=1.0
# col=out_h1_FUZ_FIBO_178_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_178_G2(t+1), value=0.0
# col=out_h1_FUZ_FIBO_178_G3(t+1), value=0.0
# col=out_h1_FUZ_FIBO_178_G4(t+1), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G0(t+1), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G1(t+1), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G2(t+1), value=0.5624063707319682
# col=out_h1_FUZ_FIBO_EXTN_G3(t+1), value=0.4375936292680319
# col=out_h1_FUZ_FIBO_EXTN_G4(t+1), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G3(t+1), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G4(t+1), value=1.0
# col=out_h1_FUZ_CHHI_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G3(t+1), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G4(t+1), value=1.0
# col=out_h1_FUZ_CHLO_DISTANCE_G0(t+1), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G1(t+1), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G2(t+1), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G3(t+1), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G4(t+1), value=1.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G0(t+2), value=1.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G1(t+2), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G2(t+2), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G3(t+2), value=0.0
# col=out_h1_FUZ_SMA_SLOW_DISTANCE_G4(t+2), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G0(t+2), value=0.8530593906010313
# col=out_h1_FUZ_SMA_MID_DISTANCE_G1(t+2), value=0.14694060939896875
# col=out_h1_FUZ_SMA_MID_DISTANCE_G2(t+2), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G3(t+2), value=0.0
# col=out_h1_FUZ_SMA_MID_DISTANCE_G4(t+2), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G0(t+2), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G1(t+2), value=0.16105350411885866
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G2(t+2), value=0.8389464958811413
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G3(t+2), value=0.0
# col=out_h1_FUZ_SMA_FAST_DISTANCE_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_023_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_023_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_023_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_023_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_023_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_038_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_038_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_038_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_038_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_038_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_050_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_050_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_050_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_050_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_050_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_061_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_061_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_061_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_061_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_061_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_078_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_078_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_078_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_078_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_078_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_RETR_G0(t+2), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_RETR_G4(t+2), value=1.0
# col=out_h1_FUZ_FIBO_123_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_123_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_123_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_123_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_123_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_138_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_138_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_138_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_138_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_138_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_150_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_150_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_150_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_150_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_150_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_161_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_161_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_161_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_161_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_161_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_178_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_178_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_178_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_178_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_178_G4(t+2), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G0(t+2), value=1.0
# col=out_h1_FUZ_FIBO_EXTN_G1(t+2), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G2(t+2), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G3(t+2), value=0.0
# col=out_h1_FUZ_FIBO_EXTN_G4(t+2), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G0(t+2), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G1(t+2), value=0.0
# col=out_h1_FUZ_SR_DISTANCE_G2(t+2), value=0.21961860609064646
# col=out_h1_FUZ_SR_DISTANCE_G3(t+2), value=0.7803813939093536
# col=out_h1_FUZ_SR_DISTANCE_G4(t+2), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G0(t+2), value=1.0
# col=out_h1_FUZ_CHHI_DISTANCE_G1(t+2), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G2(t+2), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G3(t+2), value=0.0
# col=out_h1_FUZ_CHHI_DISTANCE_G4(t+2), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G0(t+2), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G1(t+2), value=0.9485546968097274
# col=out_h1_FUZ_CHLO_DISTANCE_G2(t+2), value=0.051445303190272615
# col=out_h1_FUZ_CHLO_DISTANCE_G3(t+2), value=0.0
# col=out_h1_FUZ_CHLO_DISTANCE_G4(t+2), value=0.0
